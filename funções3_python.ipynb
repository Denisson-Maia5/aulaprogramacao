# %% [markdown]
# <a href="https://colab.research.google.com/github/Denisson-Maia5/aulaprogramacao/blob/main/fun%C3%A7%C3%B5es3_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
####### Exercios
#1 Crie uma função chamada potencia(n,expo) que recebe um número e o expoente e retorna o valor da exponenciação
##2 Faça uma função area(base, altura), que calcula area de um retangulo.
##3 Escreva uma função que caucule o IMC de um individuo, que recebendo o peso e a altura
##4 Crie uma função que aplica um desconto a um preço dado em um produto




####### Exercios
# Crie uma função chamada potencia(n,expo) que recebe um número e o expoente e retorna o valor da exponenciação
def potencia(n, expo):
  return n ** expo
print(potencia(3, 4))

# %%
#Fórmula IMC = peso/altura**2
def IMC(peso,altura):
 return  peso / altura**2

def classificaIMC(peso, altura):
 valorIMC = IMC(peso, altura)
 if (valorIMC > 30):
  return 'obeso!'
 elif (valorIMC > 25):
  return 'sobrepeso!'
 elif (valorIMC > 18.5):
  return 'eutotrófico!'
 else:
  return 'magro!'

# %%
peso = float(input('Digite seu peso: '))
altura = float(input('Digite sua altura: '))
print(classificaIMC(peso, altura))
# Out:
# Digite seu peso: 70
# Digite sua altura: 1.79
# eutotrófico!

# %%
### IMC < 18,5 - Magro
### 18.5 < IMC 24,9 - Eutotròfico
### 25,0 < IMC 29,9 - Sobrepeso
### IMC > 30 - obeso

# %%
# ex 2
def area(base, altura):
  forma = verificaForma(base, altura)
  if forma == 0:
    return f'A área do retangulo é {base * altura}'
  else:
    return f'A aréa do quadrado é {base * altura}'
def verificaForma(base, altura):
 if base == altura: #se for quadrado 1,se for retangulo 0
   return 1
 else:
   return 0
print(area(6, 6))
# Out:
# A aréa do quadrado é 36

# %%
#Crie outra função que verifique se a figura é um quadrado ou um retangulo, e depois calcula sua area
